# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
import io
def get_curve(txt):
    out = io.BytesIO(txt)
    out.seek(0)
    return np.load(out)

# %%
# cesta k .db suboru - zmenit na spravnu cestu
FILEPATH = '/home/jovyan/data/lightning/data-upjs/overcontact.db'
# vytvorenie connection na subor .db v sqllite formate
conn = sqlite3.connect(FILEPATH)

# %%
# nacitanie ake su tabulky v databaze (to len aby bolo jasne ako sa to zistit - realne su dve - parameters a curves)
sql_query = """SELECT name FROM sqlite_master WHERE type='table';"""
cursor = conn.cursor()
cursor.execute(sql_query)
print(cursor.fetchall())
# Out:
# [('parameters',), ('curves',), ('auxiliary',)]

# %%
df_parameters = pd.read_sql_query("SELECT id, overcontact FROM parameters", conn)


df_parameters.head()
# Out:
#         id  overcontact
# 0  5525038            1
# 1  5525039            1
# 2  5525040            1
# 3  5525041            1
# 4  5525042            1

# %%
df_parameters
# Out:
#              id  overcontact
# 0       5525038            1
# 1       5525039            1
# 2       5525040            1
# 3       5525041            1
# 4       5525042            1
# ...         ...          ...
# 93287  74138899            1
# 93288  74138900            1
# 93289  74138901            1
# 93290  74138902            1
# 93291  74138903            1
#
# [93292 rows x 2 columns]

# %%
# df_parameters = df_parameters.sample(10000)
df_parameters.head(70)
# Out:
#          id  overcontact
# 0   5525038            1
# 1   5525039            1
# 2   5525040            1
# 3   5525041            1
# 4   5525042            1
# ..      ...          ...
# 65  5525103            1
# 66  5525104            1
# 67  5525105            1
# 68  5525106            1
# 69  5525107            1
#
# [70 rows x 2 columns]

# %%
df_parameters.shape
# Out:
# (93292, 2)

# %%
for col in df_parameters.columns:
    print(col)
# Out:
# id
# overcontact

# %%
# for i in df_parameters['overcontact']:
#     if i == 1:
#         print("som jeden")

# %%
df_curves = pd.read_sql_query("SELECT * FROM curves ORDER BY RANDOM() LIMIT 1000", conn)
conn.close()

# %%
df_curves
# Out:
#            id                                          Bessell_U  \
# 0    42063832  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    57356644  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    26977869  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    49281092  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    63938464  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..        ...                                                ...
# 995  41634847  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  34412032  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  56080953  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  56294520  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  56504332  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                              Bessell_B  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                              Bessell_V  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b"\x93NUMPY\x01\x00v\x00{'descr': '<f8', 'fort...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                              Bessell_R  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                              Bessell_I  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                SLOAN_u  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                SLOAN_g  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                SLOAN_r  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                SLOAN_i  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                SLOAN_z  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
#                                                 Kepler  \
# 0    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 1    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 2    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 3    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 4    b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# ..                                                 ...
# 995  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 996  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 997  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 998  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
# 999  b'\x93NUMPY\x01\x00v\x00{\'descr\': \'<f8\', \...
#
# Bessell_B    [0.5792848679186989, 0.5794241438095112, 0.579...
# Bessell_V    [0.6018235059449859, 0.6019571864398205, 0.602...
# Bessell_R    [0.6175313042321812, 0.6176602250093857, 0.618...
# Bessell_I    [0.6355738390422342, 0.6356977284338816, 0.636...
# SLOAN_u      [0.5940914058207966, 0.5942266464647575, 0.594...
# SLOAN_g      [0.5867139061349476, 0.5868513782019417, 0.587...
# SLOAN_r      [0.6146425210045988, 0.6147723486307083, 0.615...
# SLOAN_i      [0.631384132919761, 0.6315092183276317, 0.6320...
# SLOAN_z      [0.6400426778971585, 0.6401650342356335, 0.640...
# Kepler       [0.6080977781314637, 0.608229590012136, 0.6087...
# GaiaDR2      [0.6070609596721629, 0.6071923422143255, 0.607...
# TESS         [0.6235714454017155, 0.6236998499572666, 0.624...
# Name: 78, dtype: object

# %%
for c in my_curves:
    plt.plot(c)
    
plt.show()

# %%
df1 = df_curves[["id","Bessell_U", "Bessell_B", "Bessell_V", "Bessell_R", "Bessell_I", "SLOAN_u", "SLOAN_g" , "SLOAN_r" , "SLOAN_i" , "SLOAN_z" , "Kepler" , "GaiaDR2" , "TESS" ]]
df2 = df_parameters[["id", "overcontact"]]
df_merged = pd.merge(df1,df2,on="id")
df_merged["Bessell_U"] = df_merged["Bessell_U"].apply(get_curve)
df_merged["Bessell_V"] = df_merged["Bessell_V"].apply(get_curve)
df_merged["Bessell_R"] = df_merged["Bessell_R"].apply(get_curve)
df_merged["Bessell_I"] = df_merged["Bessell_I"].apply(get_curve)
df_merged["Bessell_B"] = df_merged["Bessell_B"].apply(get_curve)

df_merged["SLOAN_u"] = df_merged["SLOAN_u"].apply(get_curve)
df_merged["SLOAN_g"] = df_merged["SLOAN_g"].apply(get_curve)
df_merged["SLOAN_r"] = df_merged["SLOAN_r"].apply(get_curve)
df_merged["SLOAN_i"] = df_merged["SLOAN_i"].apply(get_curve)
df_merged["SLOAN_z"] = df_merged["SLOAN_z"].apply(get_curve)

df_merged["Kepler"] = df_merged["Kepler"].apply(get_curve)
df_merged["GaiaDR2"] = df_merged["GaiaDR2"].apply(get_curve)
df_merged["TESS"] = df_merged["TESS"].apply(get_curve)


df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1000 non-null   int64
#  1   Bessell_U    1000 non-null   object
#  2   Bessell_B    1000 non-null   object
#  3   Bessell_V    1000 non-null   object
#  4   Bessell_R    1000 non-null   object
#  5   Bessell_I    1000 non-null   object
#  6   SLOAN_u      1000 non-null   object
#  7   SLOAN_g      1000 non-null   object
#  8   SLOAN_r      1000 non-null   object
#  9   SLOAN_i      1000 non-null   object
#  10  SLOAN_z      1000 non-null   object
#  11  Kepler       1000 non-null   object
#  12  GaiaDR2      1000 non-null   object
#  13  TESS         1000 non-null   object
#  14  overcontact  1000 non-null   int64
# dtypes: int64(2), object(13)
# memory usage: 125.0+ KB

# %%
df_merged.to_pickle("overcontact_1_all_filters_1k.pkl")
